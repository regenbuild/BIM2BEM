# %%
from topologicpy.Vertex import Vertex
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from topologicpy.Vertex import Vertex
#
# ModuleNotFoundError: No module named 'topologicpy'

# %%
from specklepy.api import operations
from specklepy.api.client import SpeckleClient
from specklepy.api.credentials import get_default_account
from specklepy.transports.server import ServerTransport
from specklepy.objects.geometry import GEOMETRY

HOST = 'https://speckle.xyz/'
STREAM_ID = "c9dc464658"
COMMIT_ID = "3b6b5d5b74"

client = SpeckleClient(host=HOST)
account = get_default_account()
client.authenticate_with_account(account)

commit = client.commit.get(STREAM_ID, COMMIT_ID)

if commit is not None:
    transport = ServerTransport(client=client, stream_id=STREAM_ID)
    res = operations.receive(commit.referencedObject, transport)

    upload_date = commit.createdAt
    name_of_commit = commit.message
    object_count = res.totalChildrenCount
    referenced_object = commit.referencedObject
        

    print(f'Upload Date: {upload_date}')
    print(f'Name of Commit: {name_of_commit}')
    print(f'Object Count: {object_count}')
    print(referenced_object)
    Base=[]
    

    print(res.elements)    
    for ref in res.elements:
        print(ref)
        Base.append(ref)
    print(Base)

    # Assuming commit.referencedObject is of type Base
if commit.referencedObject:
    base_object = commit.referencedObject
    if isinstance(base_object, Base):
        if 'data' in base_object:
            geometry_data = base_object['data']
            # Now you have the geometry data, and you can process it further
            print(f'Geometry Data: {geometry_data}')
        else:
            print('No geometry data found in the referenced object.')
    else:
        print('Referenced object is not of type Base.')
else:
    print('No referenced object found in the commit.')
# Out:
# Upload Date: 2024-02-23 01:51:33+00:00
# Name of Commit: Sent everything
# Object Count: 23
# d35a82425e336a5f4b08a507bf39553b
# ...

# %%
from specklepy.api import operations
from specklepy.api.client import SpeckleClient
from specklepy.api.credentials import get_default_account
from specklepy.transports.server import ServerTransport
from specklepy.objects.geometry import GEOMETRY

HOST = 'https://speckle.xyz/'
STREAM_ID = "7af871c1b93"
COMMIT_ID = "088f88ad62"

client = SpeckleClient(host=HOST)
account = get_default_account()
client.authenticate_with_account(account)

commit = client.commit.get(STREAM_ID, COMMIT_ID)

if commit is not None:
    transport = ServerTransport(client=client, stream_id=STREAM_ID)
    res = operations.receive(commit.referencedObject, transport)

    upload_date = commit.createdAt
    name_of_commit = commit.message
    object_count = res.totalChildrenCount
    referenced_object = commit.referencedObject


    print(f'Upload Date: {upload_date}')
    print(f'Name of Commit: {name_of_commit}')
    print(f'Object Count: {object_count}')
    print(referenced_object)

    print(res.elements)
    for ref in res.elements:
        print(ref)
        Base.append(ref)  # Assuming you want to append to an existing Base list
    print(Base)

    # Check if referencedObject has a 'type' attribute that matches expected type
    if commit.referencedObject and hasattr(commit.referencedObject, 'type') and commit.referencedObject.type == 'Base':
        base_object = commit.referencedObject
        if 'data' in base_object:
            geometry_data = base_object['data']
            # Now you have the geometry data, and you can process it further
            print(f'Geometry Data: {geometry_data}')
        else:
            print('No geometry data found in the referenced object.')
    else:
        print('Referenced object is not of type Base.')
else:
    print('No referenced object found in the commit.')
# Out:
# Upload Date: 2023-08-01 10:04:15.199000+00:00
# Name of Commit: Sent 52 elements from Rhino.
# Object Count: 610
# e5262a6fb51540974e6d07ac60b7fe5c
# [Collection(id: 85c66ce4a2654f68e13fd2f292ea5231, speckle_type: Speckle.Core.Models.Collection, totalChildrenCount: 0), Collection(id: fe7b8733254f25544e5d3b674f26846e, speckle_type: Speckle.Core.Models.Collection, totalChildrenCount: 0), Collection(id: 0faa4efb5f3890661972a46c0c2713b4, speckle_type: Speckle.Core.Models.Collection, totalChildrenCount: 0), Collection(id: ae56dc0eee1d55313dc288dc9a68096a, speckle_type: Speckle.Core.Models.Collection, totalChildrenCount: 0), Collection(id: 968b2ad2937bcfdcbd140dd54122c042, speckle_type: Speckle.Core.Models.Collection, totalChildrenCount: 0), Collection(id: 581a822cdaa5c2972783510d57617f73, speckle_type: Speckle.Core.Models.Collection, totalChildrenCount: 0)]
# Collection(id: 85c66ce4a2654f68e13fd2f292ea5231, speckle_type: Speckle.Core.Models.Collection, totalChildrenCount: 0)
# ...

# %%
from specklepy.api import operations
from specklepy.api.client import SpeckleClient
from specklepy.api.credentials import get_default_account
from specklepy.transports.server import ServerTransport
from specklepy.objects.geometry import GEOMETRY

HOST = 'https://speckle.xyz/'
STREAM_ID = "c9dc464658"
COMMIT_ID = "3b6b5d5b74"

client = SpeckleClient(host=HOST)
account = get_default_account()
client.authenticate_with_account(account)

commit = client.commit.get(STREAM_ID, COMMIT_ID)

if commit is not None:
    transport = ServerTransport(client=client, stream_id=STREAM_ID)
    res = operations.receive(commit.referencedObject, transport)

    upload_date = commit.createdAt
    name_of_commit = commit.message
    object_count = res.totalChildrenCount
    referenced_object = commit.referencedObject

    print(f'Upload Date: {upload_date}')
    print(f'Name of Commit: {name_of_commit}')
    print(f'Object Count: {object_count}')
    print(referenced_object)

    print(res.elements)
    for ref in res.elements:
        print(ref)
        Base.append(ref)  # Assuming you want to append to an existing Base list
    print(Base)

    # Try to access data only if 'data' key exists in referenced object
    if referenced_object and 'data' in referenced_object:
        geometry_data = referenced_object['data']
        # Now you have the geometry data, and you can process it further
        print(f'Geometry Data: {geometry_data}')
    else:
        print('No geometry data found in the referenced object.')
else:
    print('No referenced object found in the commit.')
# Out:
# Upload Date: 2024-02-23 01:51:33+00:00
# Name of Commit: Sent everything
# Object Count: 23
# d35a82425e336a5f4b08a507bf39553b
# ...

# %%
from specklepy.api import operations
from specklepy.api.client import SpeckleClient
from specklepy.api.credentials import get_default_account
from specklepy.transports.server import ServerTransport
from specklepy.objects.geometry import Geometry

HOST = 'https://speckle.xyz/'
STREAM_ID = "c9dc464658"
COMMIT_ID = "3b6b5d5b74"

client = SpeckleClient(host=HOST)
account = get_default_account()
client.authenticate_with_account(account)

commit = client.commit.get(STREAM_ID, COMMIT_ID)

if commit is not None:
    transport = ServerTransport(client=client, stream_id=STREAM_ID)
    res = operations.receive(commit.referencedObject, transport)

    upload_date = commit.createdAt
    name_of_commit = commit.message
    object_count = res.totalChildrenCount
    referenced_object = commit.referencedObject

    print(f'Upload Date: {upload_date}')
    print(f'Name of Commit: {name_of_commit}')
    print(f'Object Count: {object_count}')
    print(referenced_object)

    print(f'Elements:')
    for element in res.elements:
        print(element)
        # Check if element has a 'geometry' attribute
        if hasattr(element, 'geometry'):
            geometry = element.geometry
            # Check if geometry is of type Geometry
            if isinstance(geometry, Geometry):
                # Access and process geometry data here
                print(f'Found geometry data: {geometry}')
                # You can access specific properties of the geometry object here (e.g., vertices, faces, etc.)
                # Refer to Speckle documentation for available properties

else:
    print('No referenced object found in the commit.')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 5
#       3 from specklepy.api.credentials import get_default_account
#       4 from specklepy.transports.server import ServerTransport
# ----> 5 from specklepy.objects.geometry import Geometry
#       7 HOST = 'https://speckle.xyz/'
#       8 STREAM_ID = "c9dc464658"
#
# ImportError: cannot import name 'Geometry' from 'specklepy.objects.geometry' (c:\Users\DARSHAN D\AppData\Local\Programs\Python\Python312\Lib\site-packages\specklepy\objects\geometry.py)

# %%
from specklepy.api import operations
from specklepy.api.client import SpeckleClient
from specklepy.api.credentials import get_default_account
from specklepy.transports.server import ServerTransport
from specklepy.objects.geometry import GEOMETRY
from topologicpy.Vertex import Vertex
from topologicpy.Edge import Edge
from topologicpy.Wire import Wire
from topologicpy.Face import Face
from topologicpy.Shell import Shell
from topologicpy.Cell import Cell
from topologicpy.CellComplex import CellComplex
from topologicpy.Cluster import Cluster
from topologicpy.Topology import Topology
from topologicpy.Graph import Graph
from topologicpy.Vector import Vector
from topologicpy.Dictionary import Dictionary
from topologicpy.Helper import Helper
from topologicpy.Plotly import Plotly
from topologicpy.Speckle import Speckle

HOST = 'https://speckle.xyz/'
STREAM_ID = "c9dc464658"
COMMIT_ID = "3b6b5d5b74"

client = SpeckleClient(host=HOST)
account = get_default_account()
client.authenticate_with_account(account)

commit = client.commit.get(STREAM_ID, COMMIT_ID)
stream=client.stream.get(STREAM_ID)
stream_id= stream.id
print(stream_id)

if commit is not None:
    transport = ServerTransport(client=client, stream_id=STREAM_ID)
    res = operations.receive(commit.referencedObject, transport)

    upload_date = commit.createdAt
    name_of_commit = commit.message
    object_count = res.totalChildrenCount
    referenced_object = commit.referencedObject

    print(f'Upload Date: {upload_date}')
    print(f'Name of Commit: {name_of_commit}')
    print(f'Object Count: {object_count}')
    print(referenced_object)
    Base=[]

    print(res.elements)
    for ref in res.elements:
        print(ref)
        Base.append(ref)  # Assuming you want to append to an existing Base list
    print(Base)
# Out:
# c9dc464658
# Upload Date: 2024-02-23 01:51:33+00:00
# Name of Commit: Sent everything
# Object Count: 23
# d35a82425e336a5f4b08a507bf39553b
# ...
